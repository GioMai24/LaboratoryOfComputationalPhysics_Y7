# %% [markdown]
# # Pandas
#
# The `numpy` module is excellent for numerical computations, but to handle missing data or arrays with mixed types takes more work. The `pandas` module is currently the most widely used tool for data manipulation, providing high-performance, easy-to-use data structures and advanced data analysis tools.
#
# In particular `pandas` features:
#
# * A fast and efficient "DataFrame" object for data manipulation with integrated indexing;
# * Tools for reading and writing data between in-memory data structures and different formats (CSV, Excel, SQL, HDF5);
# * Intelligent data alignment and integrated handling of missing data;
# * Intelligent label-based slicing, fancy indexing, and subsetting of large data sets;
# * Aggregating or transforming data with a powerful "group-by" engine;
# * High performance merging and joining of data sets;
# * Hierarchical axis indexing provides an intuitive way of working with high-dimensional data in a lower-dimensional data structure;
# * Time series-functionalities;
# * Highly optimized for performance, with critical code paths written in Cython or C.

# %% [markdown]
# ### Notes
# Today: operation along columns.
# Pandas support objects with different types of data, unlike Numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series
#
# Series are completely equivalent to 1D array but with axis labels and the possibility to store heterogeneous elements. Of paramount importance are the time-series, used to define time evolutions of a phenomenon.
#
# ### Notes
# Can label each entry

# %%
from string import ascii_lowercase as letters

# Creating a series, accessing indexes, values and values by their index 
xs = pd.Series(np.arange(10)*0.5, index=tuple(letters[:10]))
print ("xs:", xs,'\n')
print ("xs indexes:",xs.index,'\n')
# Values of the Series are actually a numpy array
print ("xs values:", xs.values, type(xs.values),'\n')
print (xs['f'], xs.f, xs.h, '\n')
print (xs[['d', 'f', 'h']], '\n')
print (type(xs[['d', 'f', 'h']]), '\n')
display(xs)
# Out:
# xs: a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# xs indexes: Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='object')
#
# xs values: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5] <class 'numpy.ndarray'>
#
# 2.5 2.5 3.5
#
# d    1.5
# f    2.5
# h    3.5
# dtype: float64
#
# <class 'pandas.core.series.Series'>
# a    0.0
# b    0.5
# c    1.0
# d    1.5
# e    2.0
# f    2.5
# g    3.0
# h    3.5
# i    4.0
# j    4.5
# dtype: float64

# %%
# Extracting elements and operations: same as numpy array
print (xs[:3],'\n')
print (xs[7:], '\n')
print (xs[::3], '\n')
print (xs[xs>3], '\n')
print (np.exp(xs), '\n')
print (np.mean(xs), np.std(xs), '\n')
# Out:
# a    0.0
# b    0.5
# c    1.0
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a    0.0
# d    1.5
# g    3.0
# j    4.5
# dtype: float64
#
# h    3.5
# i    4.0
# j    4.5
# dtype: float64
#
# a     1.000000
# b     1.648721
# c     2.718282
# d     4.481689
# e     7.389056
# f    12.182494
# g    20.085537
# h    33.115452
# i    54.598150
# j    90.017131
# dtype: float64
#
# 2.25 1.4361406616345072

# %%
# Series can be created from python dictionary too.
# Not that the elements can be whatever!
d = {'b' : 1, 'a' : 'cat', 'c' : [2,3]}
pd.Series(d)
# Out:
# b         1
# a       cat
# c    [2, 3]
# dtype: object

# %% [markdown]
# A key difference between Series and ndarray is that operations between Series automatically align the data based on label. Thus, you can write computations without considering whether the Series involved have the same labels.

# %%
s = pd.Series(np.random.randn(5), index=tuple(letters[:5]))
print(s)
s = s[1:] + s[:-1]  # Sum element by element, ignore first entry of first series, and last element of second series
print(s)
# Out:
# a   -0.053436
# b    0.607265
# c   -1.550207
# d    1.673346
# e   -0.088467
# dtype: float64
# a         NaN
# b    1.214529
# c   -3.100414
# d    3.346691
# e         NaN
# dtype: float64

# %% [markdown]
# ### Time series
#
# Time series are very often used to profile the behaviour of a quantity as a function of time. Pandas has a special index for that, `DatetimeIndex`, that can be created e.g. with the function `pd.data_range()`

# %%
# to define a date, the datetime module is very useful
import datetime as dt
date = dt.date.today()
print(date)

date = dt.datetime(2024,11,27,10,45,10,15)  # Year, Month, day, hour, minute, second, millisecond
print (date)

# otherwise, several notations are interpreted too
date = 'Nov 27 2024'  # It's just a string, but can be interpreted by pandas commands

# or alternatively
date = '27/11/2024 10:45:00'
print (date)

days = pd.date_range(date, periods=7, freq='D')
print (days)

seconds = pd.date_range(date, periods=3600, freq='s')
print (seconds)
# Out:
# 2025-01-19
# 2024-11-27 10:45:10.000015
# 27/11/2024 10:45:00
# DatetimeIndex(['2024-11-27 10:45:00', '2024-11-28 10:45:00',
#                '2024-11-29 10:45:00', '2024-11-30 10:45:00',
#                '2024-12-01 10:45:00', '2024-12-02 10:45:00',
#                '2024-12-03 10:45:00'],
#               dtype='datetime64[ns]', freq='D')
# DatetimeIndex(['2024-11-27 10:45:00', '2024-11-27 10:45:01',
#                '2024-11-27 10:45:02', '2024-11-27 10:45:03',
#                '2024-11-27 10:45:04', '2024-11-27 10:45:05',
#                '2024-11-27 10:45:06', '2024-11-27 10:45:07',
#                '2024-11-27 10:45:08', '2024-11-27 10:45:09',
#                ...
#                '2024-11-27 11:44:50', '2024-11-27 11:44:51',
#                '2024-11-27 11:44:52', '2024-11-27 11:44:53',
#                '2024-11-27 11:44:54', '2024-11-27 11:44:55',
#                '2024-11-27 11:44:56', '2024-11-27 11:44:57',
#                '2024-11-27 11:44:58', '2024-11-27 11:44:59'],
#               dtype='datetime64[ns]', length=3600, freq='s')

# %% [markdown]
# To learn more about the frequency strings, please see this [link](http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)
#
#
# Timestamped data is the most basic type of time series data that associates values with points in time. For pandas objects it means using the points in time.
#
# functions like `pd.to_datetime` can be used, for instance, when reading information as string from a dataset.
#
# Timestamp is the pandas equivalent of python’s Datetime and is interchangeable with it in most cases.

# %%
tstamp = pd.Timestamp(dt.datetime(2020, 11, 9))

# internally it counts the nanoseconds from January 1st 19
#tstamp = pd.Timestamp(dt.datetime(1970, 1, 1, 0, 0, 0, 1))
print(tstamp.value)

# when creating a timestamp the format can be explicitly passed
ts = pd.to_datetime('2010/11/12', format='%Y/%m/%d')
print (type(ts))
print (ts.value)
ts = pd.to_datetime('12-11-2010 00:00', format='%d-%m-%Y %H:%M')
print (ts)
print (ts.value)
# Out:
# 1604880000000000000
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 1289520000000000000
# 2010-11-12 00:00:00
# 1289520000000000000

# %% [markdown]
# A standard series can be created and (range of) elements can be used as indexes

# %%
tseries = pd.Series(np.random.normal(10, 1, len(days)), index=days)
# Extracting elements
print (tseries[0:4], '\n')
print (tseries['2024-11-27':'2024-12-03'], '\n') # Note - includes end time
# Out:
# 2024-11-27 10:45:00     9.115253
# 2024-11-28 10:45:00     9.165639
# 2024-11-29 10:45:00    11.137142
# 2024-11-30 10:45:00     9.353782
# Freq: D, dtype: float64
#
# 2024-11-27 10:45:00     9.115253
# 2024-11-28 10:45:00     9.165639
# 2024-11-29 10:45:00    11.137142
# 2024-11-30 10:45:00     9.353782
# 2024-12-01 10:45:00    10.319753
# 2024-12-02 10:45:00     9.752423
# 2024-12-03 10:45:00    10.141622
# Freq: D, dtype: float64

# %% [markdown]
# `pd.to_datetime` can also be used to create a `DatetimeIndex`:

# %%
pd.to_datetime([1, 2, 3, 4], unit='D', origin=pd.Timestamp('1980-02-03'))
# Out:
# DatetimeIndex(['1980-02-04', '1980-02-05', '1980-02-06', '1980-02-07'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## DataFrame
#
# A pandas DataFrame is like a simple tabular spreadsheet. For future reference (or for people already familiar with R), a pandas DataFrame is very similar to the R DataFrame.
#
# Each column in a DataFrame is a Series object.
#
# The element can be whatever, missing data are dealt with too (as NaN)
#
# ### Notes
#
# Columns -> labels for variables, each column is a pandas series
#
# Indexes -> rows
#
# Things are broadcasted so as to have proper dimensions

# %% [markdown]
# ### DataFrame creation
#
# A DataFrame can be created implicitly, with, e.g., a DatatimeIndex object as index:

# %%
entries=10
dates=pd.date_range('11/27/2024 10:45:00',freq='h', periods=entries)
df = pd.DataFrame(np.random.randn(entries,4), index=dates, columns=['A','B','C','D'])
df
# Out:
#                             A         B         C         D
# 2024-11-27 10:45:00 -1.181118 -0.849266  0.234035  0.302261
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355 -0.087796
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189 -0.576610
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974 -0.667978
# 2024-11-27 14:45:00 -0.404912 -0.048771  0.912216 -0.138209
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  0.218364
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  0.376416
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  1.771187
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  0.055485
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  1.050346

# %% [markdown]
# or by means of a dictionary:

# %%
df2 = pd.DataFrame(
    { 'A' : 1.,
      'B' : pd.Timestamp('20130102'),
      'C' : pd.Series(1,index=range(4),dtype='float32'),
      'D' : np.arange(7,11),
      'E' : pd.Categorical(["test","train","test", 'train']),
    }
    )
df2

# check what happens if D and E had different lenghts
# Out:
#      A          B    C   D      E
# 0  1.0 2013-01-02  1.0   7   test
# 1  1.0 2013-01-02  1.0   8  train
# 2  1.0 2013-01-02  1.0   9   test
# 3  1.0 2013-01-02  1.0  10  train

# %% [markdown]
# ### Viewing Data

# %%
df.head(2)
# Out:
#                             A         B         C         D
# 2024-11-27 10:45:00 -1.181118 -0.849266  0.234035  0.302261
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355 -0.087796

# %%
df.tail(4)
# Out:
#                             A         B         C         D
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  0.376416
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  1.771187
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  0.055485
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  1.050346

# %%
df.index
# Out:
# DatetimeIndex(['2024-11-27 10:45:00', '2024-11-27 11:45:00',
#                '2024-11-27 12:45:00', '2024-11-27 13:45:00',
#                '2024-11-27 14:45:00', '2024-11-27 15:45:00',
#                '2024-11-27 16:45:00', '2024-11-27 17:45:00',
#                '2024-11-27 18:45:00', '2024-11-27 19:45:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[-1.18111827, -0.84926597,  0.23403464,  0.30226124],
#        [-1.0107312 ,  2.19185026, -1.23635516, -0.08779566],
#        [-0.26831708, -0.31179995, -0.48818928, -0.5766103 ],
#        [ 0.97901897,  1.41810679, -1.14197413, -0.66797821],
#        [-0.40491162, -0.04877107,  0.91221584, -0.13820856],
#        [ 1.41862046,  2.70826303,  0.83441113,  0.21836419],
#        [ 0.86555611,  0.05478951, -1.10497686,  0.37641596],
#        [-0.08418937, -0.31633443, -0.18780657,  1.77118652],
#        [-0.97798529,  0.29947723, -0.46868706,  0.05548485],
#        [-1.39900508, -0.30141544, -1.18125107,  1.05034554]])

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0
# %%
# getting an individual element
print (df.loc[dates[1],'A'])

# equivalently
print (df.at[dates[1],'A'])  # Notice that .at is faster than .loc, since it's optimized to get a single value
# Out:
# -1.0107311994728065
# -1.0107311994728065

# %% [markdown]
# ### Selecting by position

# %%
# select via the position of the passed integers:
print (df.iloc[3],'\n')

# notation similar to numpy/python
print (df.iloc[3:5,0:2])
# Out:
# A    0.979019
# B    1.418107
# C   -1.141974
# D   -0.667978
# Name: 2024-11-27 13:45:00, dtype: float64
#
#                             A         B
# 2024-11-27 13:45:00  0.979019  1.418107
# 2024-11-27 14:45:00 -0.404912 -0.048771

# %%
# selecting raws 1,2 and 4 for columns 0 and 2
df.iloc[[1,2,4],[0,2]]
# Out:
#                             A         C
# 2024-11-27 11:45:00 -1.010731 -1.236355
# 2024-11-27 12:45:00 -0.268317 -0.488189
# 2024-11-27 14:45:00 -0.404912  0.912216

# %%
# slicing rows explicitly
print (df.iloc[1:3,:],'\n')

# slicing columns explicitly
print (df.iloc[:,1:3])

# selecting an individual element by position
print(df.iloc[1,1])
# Out:
#                             A        B         C         D
# 2024-11-27 11:45:00 -1.010731  2.19185 -1.236355 -0.087796
# 2024-11-27 12:45:00 -0.268317 -0.31180 -0.488189 -0.576610
#
#                             B         C
# 2024-11-27 10:45:00 -0.849266  0.234035
# 2024-11-27 11:45:00  2.191850 -1.236355
# 2024-11-27 12:45:00 -0.311800 -0.488189
# 2024-11-27 13:45:00  1.418107 -1.141974
# 2024-11-27 14:45:00 -0.048771  0.912216
# 2024-11-27 15:45:00  2.708263  0.834411
# 2024-11-27 16:45:00  0.054790 -1.104977
# 2024-11-27 17:45:00 -0.316334 -0.187807
# 2024-11-27 18:45:00  0.299477 -0.468687
# 2024-11-27 19:45:00 -0.301415 -1.181251
# 2.1918502576940915

# %% [markdown]
# ### Boolean index
#
# Very powerful way of filtering out data with certain features. Notation is very similar to numpy arrays.

# %%
# Filter by a boolean condition on the values of a single column
df[df['B'] > 0]
# Out:
#                             A         B         C         D
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355 -0.087796
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974 -0.667978
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  0.218364
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  0.376416
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  0.055485

# %%
# Selecting on the basis of boolean conditions applied to the whole DataFrame
df[df>0]

# a DataFrame with the same shape is returned, with NaN's where condition is not met, kills not satisfying entries, not entire rows
# Out:
#                             A         B         C         D
# 2024-11-27 10:45:00       NaN       NaN  0.234035  0.302261
# 2024-11-27 11:45:00       NaN  2.191850       NaN       NaN
# 2024-11-27 12:45:00       NaN       NaN       NaN       NaN
# 2024-11-27 13:45:00  0.979019  1.418107       NaN       NaN
# 2024-11-27 14:45:00       NaN       NaN  0.912216       NaN
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  0.218364
# 2024-11-27 16:45:00  0.865556  0.054790       NaN  0.376416
# 2024-11-27 17:45:00       NaN       NaN       NaN  1.771187
# 2024-11-27 18:45:00       NaN  0.299477       NaN  0.055485
# 2024-11-27 19:45:00       NaN       NaN       NaN  1.050346

# %% [markdown]
# ### Setting
#
# Combination of selection and setting of values

# %%
# setting values by label (same as by position)
df.at[dates[0],'A'] = 0

# setting and assigning a numpy array
df.loc[:,'D'] = np.array([5] * len(df))

# defining a brend new column
df['E'] = np.arange(len(df))*0.5

# defining a brend new column by means of a pd.Series: indexes must be the same!
df['E prime'] = pd.Series(np.arange(len(df))*2, index=df.index)

df
# Out:
#                             A         B         C    D    E  E prime
# 2024-11-27 10:45:00  0.000000 -0.849266  0.234035  5.0  0.0        0
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355  5.0  0.5        2
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189  5.0  1.0        4
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974  5.0  1.5        6
# 2024-11-27 14:45:00 -0.404912 -0.048771  0.912216  5.0  2.0        8
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5       10
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  5.0  3.0       12
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  5.0  3.5       14
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  5.0  4.0       16
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  5.0  4.5       18

# %%
def dcos(theta):
    theta = theta*(np.pi/180)
    return np.cos(theta)
 
df['cosine'] = pd.Series(df["E"].apply(dcos), index=df.index)
df
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2024-11-27 10:45:00  0.000000 -0.849266  0.234035  5.0  0.0        0  1.000000
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355  5.0  0.5        2  0.999962
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189  5.0  1.0        4  0.999848
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974  5.0  1.5        6  0.999657
# 2024-11-27 14:45:00 -0.404912 -0.048771  0.912216  5.0  2.0        8  0.999391
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5       10  0.999048
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  5.0  3.0       12  0.998630
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  5.0  3.5       14  0.998135
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  5.0  4.0       16  0.997564
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  5.0  4.5       18  0.996917

# %%
# another example of global setting
df2=df.copy()

df2[df2>0] = -df2
df2
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2024-11-27 10:45:00  0.000000 -0.849266 -0.234035 -5.0  0.0        0 -1.000000
# 2024-11-27 11:45:00 -1.010731 -2.191850 -1.236355 -5.0 -0.5       -2 -0.999962
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189 -5.0 -1.0       -4 -0.999848
# 2024-11-27 13:45:00 -0.979019 -1.418107 -1.141974 -5.0 -1.5       -6 -0.999657
# 2024-11-27 14:45:00 -0.404912 -0.048771 -0.912216 -5.0 -2.0       -8 -0.999391
# 2024-11-27 15:45:00 -1.418620 -2.708263 -0.834411 -5.0 -2.5      -10 -0.999048
# 2024-11-27 16:45:00 -0.865556 -0.054790 -1.104977 -5.0 -3.0      -12 -0.998630
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807 -5.0 -3.5      -14 -0.998135
# 2024-11-27 18:45:00 -0.977985 -0.299477 -0.468687 -5.0 -4.0      -16 -0.997564
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251 -5.0 -4.5      -18 -0.996917

# %% [markdown]
# ### Are you dealing with a Copy or a View?
#
# In general is hard to tell..

# %%
dfd = pd.DataFrame({'a': [1, 2, 3], 'b': [4, 5, 6]})

# This is likely a view
subset = dfd.loc[0:1, 'a']  
subset[0] = 100  # May affect `df`

print (dfd)

# This is a copy
subset = dfd.loc[[0, 1], 'a']  
subset[0] = 200  # Does NOT affect `df`

print (dfd)
# Out:
#      a  b
# 0  100  4
# 1    2  5
# 2    3  6
#      a  b
# 0  100  4
# 1    2  5
# 2    3  6

# %% [markdown]
# The behaviour depend on the version of Pandas and on the version of Numpy that given version of Pandas depends upon. Since Pandas 1.5 "Copy-on-Write" (CoW) is (optionally) available and as of Pandas 3.0 will be the default.
#
# With CoW chained assignemt will never work; in the following example, the view `dfd["a"]` and `df` itself are modified in one step. This will lead to a `ChainedAssignemntError`

# %%
dfd["a"][dfd["b"] > 5] = 100
dfd
# Out:
# /tmp/ipykernel_17973/449088826.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dfd["a"][dfd["b"] > 5] = 100
#      a  b
# 0  100  4
# 1    2  5
# 2  100  6

# %% [markdown]
# With copy on write this can be done by using `loc`

# %%
dfd.loc[dfd["b"] > 5, "a"] = 200
dfd
# Out:
#      a  b
# 0  100  4
# 1    2  5
# 2  200  6

# %%
kli = dfd.loc[dfd['b']>5]
display(kli)
# Out:
#      a  b
# 2  200  6

# %% [markdown]
# ### Dropping
#
# N.B.: dropping doesn't act permanently on the DataFrame, i.e. to get that do :
# ```python
# df = df.drop(....)
# ```

# %%
# Dropping by column
df.drop(['E prime'], axis=1)
display(df)
#which is equivalent to
new_df=df.drop(columns=['E prime'])
new_df
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2024-11-27 10:45:00  0.000000 -0.849266  0.234035  5.0  0.0        0  1.000000
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355  5.0  0.5        2  0.999962
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189  5.0  1.0        4  0.999848
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974  5.0  1.5        6  0.999657
# 2024-11-27 14:45:00 -0.404912 -0.048771  0.912216  5.0  2.0        8  0.999391
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5       10  0.999048
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  5.0  3.0       12  0.998630
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  5.0  3.5       14  0.998135
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  5.0  4.0       16  0.997564
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  5.0  4.5       18  0.996917
#                             A         B         C    D    E    cosine
# 2024-11-27 10:45:00  0.000000 -0.849266  0.234035  5.0  0.0  1.000000
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355  5.0  0.5  0.999962
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189  5.0  1.0  0.999848
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974  5.0  1.5  0.999657
# 2024-11-27 14:45:00 -0.404912 -0.048771  0.912216  5.0  2.0  0.999391
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5  0.999048
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  5.0  3.0  0.998630
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  5.0  3.5  0.998135
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  5.0  4.0  0.997564
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  5.0  4.5  0.996917

# %%
# Dropping by raws
# safe and always working
df.drop(df.index[[1,2,3,4]])
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2024-11-27 10:45:00  0.000000 -0.849266  0.234035  5.0  0.0        0  1.000000
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5       10  0.999048
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  5.0  3.0       12  0.998630
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  5.0  3.5       14  0.998135
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  5.0  4.0       16  0.997564
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  5.0  4.5       18  0.996917

# %%
df
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2024-11-27 10:45:00  0.000000 -0.849266  0.234035  5.0  0.0        0  1.000000
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355  5.0  0.5        2  0.999962
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189  5.0  1.0        4  0.999848
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974  5.0  1.5        6  0.999657
# 2024-11-27 14:45:00 -0.404912 -0.048771  0.912216  5.0  2.0        8  0.999391
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5       10  0.999048
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  5.0  3.0       12  0.998630
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  5.0  3.5       14  0.998135
# 2024-11-27 18:45:00 -0.977985  0.299477 -0.468687  5.0  4.0       16  0.997564
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  5.0  4.5       18  0.996917

# %%
# something like df.drop('index_name') 
# would work but the type of index must be specificed, 
# in particular with DatetimeIndex
df.drop(pd.to_datetime("2024-11-27 18:45:00"))
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2024-11-27 10:45:00  0.000000 -0.849266  0.234035  5.0  0.0        0  1.000000
# 2024-11-27 11:45:00 -1.010731  2.191850 -1.236355  5.0  0.5        2  0.999962
# 2024-11-27 12:45:00 -0.268317 -0.311800 -0.488189  5.0  1.0        4  0.999848
# 2024-11-27 13:45:00  0.979019  1.418107 -1.141974  5.0  1.5        6  0.999657
# 2024-11-27 14:45:00 -0.404912 -0.048771  0.912216  5.0  2.0        8  0.999391
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5       10  0.999048
# 2024-11-27 16:45:00  0.865556  0.054790 -1.104977  5.0  3.0       12  0.998630
# 2024-11-27 17:45:00 -0.084189 -0.316334 -0.187807  5.0  3.5       14  0.998135
# 2024-11-27 19:45:00 -1.399005 -0.301415 -1.181251  5.0  4.5       18  0.996917

# %% [markdown]
# ## Missing data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations.

# %%
df_wNan = df[df>0]
df_wNan
# Out:
#                             A         B         C    D    E  E prime    cosine
# 2024-11-27 10:45:00       NaN       NaN  0.234035  5.0  NaN      NaN  1.000000
# 2024-11-27 11:45:00       NaN  2.191850       NaN  5.0  0.5      2.0  0.999962
# 2024-11-27 12:45:00       NaN       NaN       NaN  5.0  1.0      4.0  0.999848
# 2024-11-27 13:45:00  0.979019  1.418107       NaN  5.0  1.5      6.0  0.999657
# 2024-11-27 14:45:00       NaN       NaN  0.912216  5.0  2.0      8.0  0.999391
# 2024-11-27 15:45:00  1.418620  2.708263  0.834411  5.0  2.5     10.0  0.999048
# 2024-11-27 16:45:00  0.865556  0.054790       NaN  5.0  3.0     12.0  0.998630
# 2024-11-27 17:45:00       NaN       NaN       NaN  5.0  3.5     14.0  0.998135
# 2024-11-27 18:45:00       NaN  0.299477       NaN  5.0  4.0     16.0  0.997564
# 2024-11-27 19:45:00       NaN       NaN       NaN  5.0  4.5     18.0  0.996917

# %%
# dropping raws with at least a Nan
df_wNan.dropna(how='any')
# Out:
#                            A         B         C    D    E  E prime    cosine
# 2024-11-27 15:45:00  1.41862  2.708263  0.834411  5.0  2.5     10.0  0.999048

# %%
# getting a mask
df_wNan.isna()
#df_wNan.notna()
# Out:
#                          A      B      C      D      E  E prime  cosine
# 
# Freq: h, dtype: float64

# %% [markdown]
# Let's play it hard and load (in memory) a (relatively) large dataset

# %%
# WARNING! link in past notebook was wrong!, (if needed) get the right file from:
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

file_name="./data/data_000637.txt"
data=pd.read_csv(file_name)
data.tail(10)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 1310710     1     1           36  3869211171         427        13
# 1310711     1     1           39  3869211171         430         0
# 1310712     1     1           35  3869211171         429         4
# 1310713     1     0           64  3869211171         758        18
# 1310714     1     0           60  3869211171         762         2
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18

# %% [markdown]
# Let's now do some operations among (elements of) columns

# %%
# the one-liner killing it all
data['timens']=data['TDC_MEAS']*25/30+data['BX_COUNTER']*25

# %%
data['timens']
# Out:
# 0          59371.666667
# 1          59372.500000
# 2          63848.333333
# 3          63965.833333
# 4          69020.833333
#                ...
# 1310715    19061.666667
# 1310716    19084.166667
# 1310717    19100.000000
# 1310718    19225.000000
# 1310719    19065.000000
# Name: timens, Length: 1310720, dtype: float64

# %%
# the old slooow way
def conversion(data):
    result=[]
    for i in range(len(data)): 
        result.append(data.loc[data.index[i],'TDC_MEAS']*25/30.+data.loc[data.index[i],'BX_COUNTER']*25)
    return result

data['timens']=conversion(data)

# %% [markdown]
# For tasks on extremely large datasets, libraries like [Polars](https://docs.pola.rs) or [Dask](https://www.dask.org) can offer even faster alternatives by further parallelizing or optimizing columnar operations.

# %% [markdown]
# ## Databases
# The professor doesn't often deal with operations on databases (see below)

# %% [markdown]
# ## Merge
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# ### Concat
#
# concatenation (adding rows) is straightforward

# %%
rdf = pd.DataFrame(np.random.randn(10, 4))
rdf
# Out:
#           0         1         2         3
# 0  0.703821  0.094533 -0.625481 -0.076496
# 1 -0.106580 -0.908184  0.306581 -2.140626
# 2  0.312568 -1.385127  1.699014 -0.723954
# 3  0.766084 -0.119869 -0.225178 -0.821944
# 4 -1.250664 -0.417372  0.096273  1.370987
# 5  0.025512 -0.761926  0.298167  0.087026
# 6  1.387257 -1.009834  0.415750 -2.225025
# 7  1.485174 -1.124683 -0.112476 -0.990315
# 8  0.597145  0.037802  0.254454 -0.473305
# 9  0.228404  0.854315  0.782887  1.027720

# %%
# divide it into pieaces raw-wise
pieces = [rdf[:3], rdf[3:7], rdf[7:]]
pieces
# Out:
# [          0         1         2         3
#  0  0.703821  0.094533 -0.625481 -0.076496
#  1 -0.106580 -0.908184  0.306581 -2.140626
#  2  0.312568 -1.385127  1.699014 -0.723954,
#            0         1         2         3
#  3  0.766084 -0.119869 -0.225178 -0.821944
#  4 -1.250664 -0.417372  0.096273  1.370987
#  5  0.025512 -0.761926  0.298167  0.087026
#  6  1.387257 -1.009834  0.415750 -2.225025,
#            0         1         2         3
#  7  1.485174 -1.124683 -0.112476 -0.990315
#  8  0.597145  0.037802  0.254454 -0.473305
#  9  0.228404  0.854315  0.782887  1.027720]

# %%
# put it back together
#pd.concat(pieces)

# indexes can be ignored
pd.concat(pieces, ignore_index=True)

# in case of dimension mismatch, Nan are added where needed
# Out:
#           0         1         2         3
# 0  0.703821  0.094533 -0.625481 -0.076496
# 1 -0.106580 -0.908184  0.306581 -2.140626
# 2  0.312568 -1.385127  1.699014 -0.723954
# 3  0.766084 -0.119869 -0.225178 -0.821944
# 4 -1.250664 -0.417372  0.096273  1.370987
# 5  0.025512 -0.761926  0.298167  0.087026
# 6  1.387257 -1.009834  0.415750 -2.225025
# 7  1.485174 -1.124683 -0.112476 -0.990315
# 8  0.597145  0.037802  0.254454 -0.473305
# 9  0.228404  0.854315  0.782887  1.027720

# %%
# appending a single row (as a Series)
s = rdf.iloc[3]
rdf = pd.concat([rdf,s.to_frame().T], ignore_index=True)
rdf
# Out:
#            0         1         2         3
# 0   0.703821  0.094533 -0.625481 -0.076496
# 1  -0.106580 -0.908184  0.306581 -2.140626
# 2   0.312568 -1.385127  1.699014 -0.723954
# 3   0.766084 -0.119869 -0.225178 -0.821944
# 4  -1.250664 -0.417372  0.096273  1.370987
# 5   0.025512 -0.761926  0.298167  0.087026
# 6   1.387257 -1.009834  0.415750 -2.225025
# 7   1.485174 -1.124683 -0.112476 -0.990315
# 8   0.597145  0.037802  0.254454 -0.473305
# 9   0.228404  0.854315  0.782887  1.027720
# 10  0.766084 -0.119869 -0.225178 -0.821944

# %% [markdown]
# ### Merge/Join
#
# SQL (Structured Query Language) like operations on table can be performed on DataFrames. This is all rather sophisticated, refer to the [doc](https://pandas.pydata.org/pandas-docs/stable/merging.html#merging) for more info/examples.
#
# #### Merging, Inner Join (default)
#
# Only rows with matching id values are included:

# %%
import pandas as pd

df1 = pd.DataFrame({'id': [1, 2, 3], 'name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'id': [2, 3, 4], 'age': [25, 30, 35]})

# Merge on the 'id' column
result = pd.merge(df1, df2, on='id')  # It's gonna kill Alice and 35, since they don't have compatible id
print(result)
# Out:
#    id     name  age
# 0   2      Bob   25
# 1   3  Charlie   30

# %% [markdown]
# #### Merging, Left Join
#
# A left join includes all rows from `df1` (left) and fills in `NaN` for missing matches in `df2`.

# %%
result = pd.merge(df1, df2, on='id', how='left')  # Priority is given to the left df: takes all df1 indexes
# NaNning any problematic value
print(result)
# Out:
#    id     name   age
# 0   1    Alice   NaN
# 1   2      Bob  25.0
# 2   3  Charlie  30.0

# %% [markdown]
# #### Merging, Outer Join
#
# An outer join includes all rows from both DataFrames, filling NaN for missing values

# %%
result = pd.merge(df1, df2, on='id', how='outer')
print(result)
# Out:
#    id     name   age
# 0   1    Alice   NaN
# 1   2      Bob  25.0
# 2   3  Charlie  30.0
# 3   4      NaN  35.0

# %% [markdown]
# `join` is similar to `merge` but uses index as key and has 'Left' as default

# %%
df1 = pd.DataFrame({'name': ['Alice', 'Bob', 'Charlie']}, index=[1, 2, 3])
df2 = pd.DataFrame({'age': [25, 30, 35]}, index=[2, 3, 4])

result = df1.join(df2)
print(result)
# Out:
#       name   age
# 1    Alice   NaN
# 2      Bob  25.0
# 3  Charlie  30.0

# %% [markdown]
# ## Grouping
#
# By “group by” we are referring to a process involving one or more of the following steps:
#
# * Splitting the data into groups based on some criteria
# * Applying a function to each group independently
# * Combining the results into a data structure
#
#
# Grouping is one of the most powerful and at the same time most sofisticated action you can perform with DataFrames. Mastering it is key for an effective usage of Pandas and vectorized data analysis. Reading the [documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html) or going through a [tutorial](https://realpython.com/pandas-groupby/) is warmly recommended.
#
# Let's go through a few examples:

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'C'],
    'Values': [10, 20, 30, 40, 50, 60]
}

df = pd.DataFrame(data)
display(df)
# Group by 'Category' and calculate the sum
result = df.groupby('Category').sum()
print(result)
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50
# 5        C      60
#           Values
# Category
# A             90
# B             60
# C             60

# %%
# Multiple Aggregations
result = df.groupby('Category').agg(['sum', 'mean'])
print(result)
# Out:
#          Values
#             sum  mean
# Category
# A            90  30.0
# B            60  30.0
# C            60  60.0

# %%
# Grouping by multiple columns
df = pd.DataFrame({'Category': ['A', 'A', 'B', 'B', 'C', 'C'],
                   'Type': ['X', 'Y', 'X', 'Y', 'X', 'Y'],
                   'Values': [10, 20, 30, 40, 50, 60]})

result = df.groupby(['Category', 'Type']).sum()
print(result)
# Out:
#                Values
# Category Type
# A        X         10
#          Y         20
# B        X         30
#          Y         40
# C        X         50
#          Y         60

# %%
# Trasformations using groupby(): add group averages to DataFrame
df['Group_Avg'] = df.groupby('Category')['Values'].transform('mean')
print(df)
# Out:
#   Category Type  Values  Group_Avg
# 0        A    X      10       15.0
# 1        A    Y      20       15.0
# 2        B    X      30       35.0
# 3        B    Y      40       35.0
# 4        C    X      50       55.0
# 5        C    Y      60       55.0

# %%
# filtering
filtered = df.groupby('Category').filter(lambda x: x['Values'].sum() > 50)
print(filtered)
# Out:
#   Category Type  Values  Group_Avg
# 2        B    X      30       35.0
# 3        B    Y      40       35.0
# 4        C    X      50       55.0
# 5        C    Y      60       55.0

# %%
# custom aggregation with apply()
def custom_aggregation(group):
    return pd.Series({
        'Sum': group['Values'].sum(),
        'Max': group['Values'].max(),
        'Count': group['Values'].count()
    })

result = df.groupby('Category').apply(custom_aggregation)
print(result)
# Out:
#           Sum  Max  Count
# Category
# A          30   20      2
# B          70   40      2
# C         110   60      2
# /tmp/ipykernel_17973/640594234.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = df.groupby('Category').apply(custom_aggregation)

# %%
# splitting data into groups
grouped = df.groupby('Category')

for name, group in grouped:
    print(f"Group: {name}")
    print(group)
# Out:
# Group: A
#   Category Type  Values  Group_Avg
# 0        A    X      10       15.0
# 1        A    Y      20       15.0
# Group: B
#   Category Type  Values  Group_Avg
# 2        B    X      30       35.0
# 3        B    Y      40       35.0
# Group: C
#   Category Type  Values  Group_Avg
# 4        C    X      50       55.0
# 5        C    Y      60       55.0

# %% [markdown]
# ## Multi-indexing
#
#
# Hierarchical / Multi-level indexing allows sophisticated data analysis on higher dimensional data. In essence, it enables you to store and manipulate data with an arbitrary number of dimensions in lower dimensional data structures like Series (1d) and DataFrame (2d).

# %%
tuples = list(zip(['bar', 'bar', 'baz', 'baz', 'foo', 'foo', 'qux', 'qux'],
          ['one', 'two', 'one', 'two', 'one', 'two', 'one', 'two']))
multi_index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
print (multi_index,'\n')

s = pd.Series(np.random.randn(8), index=multi_index)
print (s)
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])
#
# first  second
# bar    one      -0.798202
#        two       0.625442
# baz    one      -2.842893
#        two      -2.474444
# foo    one       0.364380
#        two      -1.151374
# qux    one      -0.688595
#        two       1.917291
# dtype: float64

# %%
gdf = pd.DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                    'B' : ['one', 'one', 'two', 'three',
                           'two', 'two', 'one', 'three'],
                    'C' : np.random.randn(8),
                    'D' : np.random.randn(8)})
gdf

# it enables further features of the groupby method,
# e.g. when group-by by multiple columns
gdf.groupby(['A','B']).sum()
# Out:
#                   C         D
# A   B
# bar one    0.734202 -0.820687
#     three -0.574877  1.511948
#     two    0.925372  0.676082
# foo one   -0.441203  0.654218
#     three -0.817346 -0.153357
#     two   -2.042508  0.867230

# %%
# stack() method “compresses” a level in the DataFrame’s columns
gdf.groupby(['A','B']).sum().stack()
# Out:
# A    B
# bar  one    C    0.734202
#             D   -0.820687
#      three  C   -0.574877
#             D    1.511948
#      two    C    0.925372
#             D    0.676082
# foo  one    C   -0.441203
#             D    0.654218
#      three  C   -0.817346
#             D   -0.153357
#      two    C   -2.042508
#             D    0.867230
# dtype: float64

# %% [markdown]
# ## Plotting
#
# Just a preview, more on the next lab class!

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts.cumsum().plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

pdf=pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
pdf = pdf.cumsum()
plt.figure(); pdf.plot(); plt.legend(loc='best')  # Best should be default dammit
