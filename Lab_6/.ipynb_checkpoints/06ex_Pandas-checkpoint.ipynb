# %% [markdown]
# ## Pandas analysis
#
# This exercise consists in analyzing a dataset containg timing information from a series of Time-to-Digital-Converters (TDC) implemented in a couple of FPGAs. Each measurement (i.e. each row of the input file) consists of a flag that specifies the type of message ('HEAD', which in this case is always 1), two addresses of the TDC providing the signal ('FPGA' and 'TDC_CHANNEL'), and the timing information ('ORBIT_CNT', 'BX_COUNTER', and 'TDC_MEAS'). Each TDC count corresponds to 25/30 ns, whereas a unit of BX_COUNTER corresponds to 25 ns, and the ORBIT_CNT is increased every 'x' BX_COUNTER. This allows to store the time in a similar way to hours, minutes and seconds.

# %%
# If you didn't download it yet, please get the relevant file now!
#!wget https://www.dropbox.com/s/xvjzaxzz3ysphme/data_000637.txt -P ~/data/

# %% [markdown]
# 1\. Create a Pandas DataFrame reading N rows of the 'data_000637.txt' dataset. Choose N to be smaller than or equal to the maximum number of rows and larger that 10k.
#
# 2\. Find out the number of BX in a ORBIT (the value 'x').
#
# 3\. Find out how much the data taking lasted. You can either make an estimate based on the fraction of the measurements (rows) you read, or perform this check precisely by reading out the whole dataset.
#
# 4\. Create a new column with the absolute time in ns (as a combination of the other three columns with timing information).
#
# 5\. Replace the values (all 1) of the HEAD column randomly with 0 or 1.
#
# 6\. Create a new DataFrame that contains only the rows with HEAD=1.
#
# 7\. Make two occupancy plots (one for each FPGA), i.e. plot the number of counts per TDC channel
#
# 8\. Use the groupby method to find out the noisy channels, i.e. the TDC channels with most counts (say the top 3)
#
# 9\. Count the number of unique orbits. Count the number of unique orbits with at least one measurement from TDC_CHANNEL=139

# %% [markdown]
# ## Explanation
# ### Dataset
# Several channels measuring time, internal cloc, address (FPGA(01)+TOC_CHANNEL), measurements: tdc -> every tick is a (25/30)ns ad 30 BX_counter bumps up. When BX_counter goes to somehting it bumps up Orbit_CNT...
#
# See theory lesson for details
#
# ---

# %%
import pandas as pd
import numpy.random
import random
import matplotlib.pyplot as plt

# %%
# 1
raw = pd.read_csv('./data/data_000637.txt')

df1 = raw.sample(random.randrange(10001, raw.shape[0]), axis=0)
df1 = df1.sort_values(by=['ORBIT_CNT', 'BX_COUNTER', 'TDC_MEAS'])
display(df1)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310719     1     0           61  3869211171         762        18
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
#
# [1106254 rows x 6 columns]

# %%
# 2 
print('BX_COUNTER MAX', maxi := raw['BX_COUNTER'].max(), '\n' f'Which means there are {maxi + 1} BX in a single orbit')
# Out:
# BX_COUNTER MAX 3563
# Which means there are 3564 BX in a single orbit

# %%
# 3
display(raw)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
# 1310719     1     0           61  3869211171         762        18
#
# [1310720 rows x 6 columns]

# %%
ini = raw.head(1)
fin = raw.tail(1)

fini = ((fin['ORBIT_CNT']*3564/30 + fin['BX_COUNTER'] + fin['TDC_MEAS']/30)*25).iloc[0]
inif = ((ini['ORBIT_CNT']*3564/30 + ini['BX_COUNTER'] + ini['TDC_MEAS']/30)*25).iloc[0]

print(fini - inif)
# Out:
# 32641573.333984375

# %%
df1['ABS_TIME']=(df1['ORBIT_CNT']*3564/30 + df1['BX_COUNTER'] + df1['TDC_MEAS']/30)*25

# %%
display(df1)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           1     0          123  3869200167        2374        26
# 1           1     0          124  3869200167        2374        27
# 2           1     0           63  3869200167        2553        28
# 3           1     0           64  3869200167        2558        19
# 4           1     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310719     1     0           61  3869211171         762        18
# 1310716     1     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     1     0          139  3869211171         769         0
#
#              ABS_TIME
# 0        1.149152e+13
# 1        1.149152e+13
# 2        1.149152e+13
# 3        1.149152e+13
# 4        1.149152e+13
# ...               ...
# 1310715  1.149156e+13
# 1310719  1.149156e+13
# 1310716  1.149156e+13
# 1310717  1.149156e+13
# 1310718  1.149156e+13
#
# [1106254 rows x 7 columns]

# %%
rng = numpy.random.default_rng()

df1 = df1.assign(HEAD=lambda x: rng.integers(2, size=len(df1['HEAD'])))

# %%
display(df1)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 0           0     0          123  3869200167        2374        26
# 1           0     0          124  3869200167        2374        27
# 2           0     0           63  3869200167        2553        28
# 3           0     0           64  3869200167        2558        19
# 4           0     0           64  3869200167        2760        25
# ...       ...   ...          ...         ...         ...       ...
# 1310715     1     0           62  3869211171         762        14
# 1310719     1     0           61  3869211171         762        18
# 1310716     0     1            4  3869211171         763        11
# 1310717     1     0           64  3869211171         764         0
# 1310718     0     0          139  3869211171         769         0
#
#              ABS_TIME
# 0        1.149152e+13
# 1        1.149152e+13
# 2        1.149152e+13
# 3        1.149152e+13
# 4        1.149152e+13
# ...               ...
# 1310715  1.149156e+13
# 1310719  1.149156e+13
# 1310716  1.149156e+13
# 1310717  1.149156e+13
# 1310718  1.149156e+13
#
# [1106254 rows x 7 columns]

# %%
heads = df1[df1['HEAD']==1]

# %%
display(heads)
# Out:
#          HEAD  FPGA  TDC_CHANNEL   ORBIT_CNT  BX_COUNTER  TDC_MEAS  \
# 6           1     0           61  3869200167        2772        14
# 11          1     0           64  3869200167        2786        19
# 9           1     0           60  3869200167        2788         7
# 21          1     0           57  3869200167        2789        10
# 20          1     1           10  3869200167        2789        14
# ...       ...   ...          ...         ...         ...       ...
# 1310713     1     0           64  3869211171         758        18
# 1310714     1     0           60  3869211171         762         2
# 1310715     1     0           62  3869211171         762        14
# 1310719     1     0           61  3869211171         762        18
# 1310717     1     0           64  3869211171         764         0
#
#              ABS_TIME
# 6        1.149152e+13
# 11       1.149152e+13
# 9        1.149152e+13
# 21       1.149152e+13
# 20       1.149152e+13
# ...               ...
# 1310713  1.149156e+13
# 1310714  1.149156e+13
# 1310715  1.149156e+13
# 1310719  1.149156e+13
# 1310717  1.149156e+13
#
# [553576 rows x 7 columns]

# %%
FP1 = df1[df1['FPGA']==1]
FP0 = df1[df1['FPGA']==0]

# %%
fig, ax = plt.subplots()
ax.set_axisbelow(True)
FP0['TDC_CHANNEL'].hist(bins=FP0['TDC_CHANNEL'].nunique(), grid=False, ax=ax)
ax.grid(axis='y', alpha=.4)
ax.set_xlim(0,140)
plt.show()

# %%
fig, ax = plt.subplots()
ax.set_axisbelow(True)
FP1['TDC_CHANNEL'].hist(bins=FP1['TDC_CHANNEL'].nunique(), grid=False, ax=ax)
ax.grid(axis='y', alpha=.4)
ax.set_xlim(0,140)
plt.show()

# %%
# I guess we want to distinguish the channel by address: FPGA, TDC_CHANNEL, if it was only by CHANNEL we could simply use
print(raw['TDC_CHANNEL'].value_counts()[:3])
print(raw.groupby(['FPGA', 'TDC_CHANNEL'], sort=False)['TDC_CHANNEL'].count().sort_values(ascending=False)[:3])
# Out:
# TDC_CHANNEL
# 139    108059
# 64      66020
# 63      64642
# Name: count, dtype: int64
# FPGA  TDC_CHANNEL
# 0     139            75617
#       64             64581
#       63             63724
# Name: TDC_CHANNEL, dtype: int64
